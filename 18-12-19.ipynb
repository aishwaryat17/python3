# %%
### TO PRINT MAX VALUE OF int

#include<stdio.h>
#include<limits.h>
void main()
{
    int a;
    a=INT_MAX;
    printf("%d",a);
}

# %%
### TO PRINT MIN VALUE OF int

#include<stdio.h>
#include<limits.h>
void main()
{
    int a;
    a=INT_MIN;
    printf("%d",a);
}

# %%
### TO PRINT ASCII VALUES

#include<stdio.h>
void main()
{
    int i;
    for(i=0;i<=200;i++)
    printf("%c=%d",i,i);
}

# %%
# To print particular ascii value
#include<stdio.h>
void main()
{
    printf("%d",'+');
}

# %%
#include<stdio.h>
void main()
{
    printf("abcd\nxyz");
    printf("abcd\fxyz");
    printf("abcd\rxyz");
    printf("abcd\txyz");
    printf("abcd\vxyz");
    printf("abcd\bxyz");
    printf("abcd\\xyz");
    printf("abcd\axyz");
    printf("abcd\'xyz");
    printf("abcd\"xyz");
}

# %%
### FORMAT SPECIFIERS
#include<stdio.h>
void main()
{
    int i=29;
    printf("%o",i);
    printf("\n%x",i);
    
}

# %%
# operators
#include<stdio.h>
void main()
{
    printf("%d",10+20);
    printf("\n%d",10+'a');
    printf("\n%d",'b'+'a');
    
}

#include<stdio.h>
void main()
{
   float a;
   a=fmod(20.5,3.2);
   printf("%f",a);
}

#include<stdio.h>
void main()
{
   int b,a=5;
   printf("%d",a++);
    printf("%d",a);
}

#include<stdio.h>
void main()
{
    int c;
    c=printf("hello\n");
    printf("\n%d",c);
}

#include <stdio.h>

int main()
{
  int a=5,b=0,c;
  c=b||a++;
  printf("%d",a);
}

# %% [markdown]
# #include <stdio.h>
#
# int main()
# {
#
#     int a=5,b=6,c;
#     c=a&b;
#     printf("%d",c);
#      c=a<<b;
#      printf("\n%d",c);
#       c=a>>b;
#       printf("\n%d",c);
#       c=a^b;
#        printf("\n%d",c);
#         c=~5;
#          printf("\n%d",c);
#
# }

# %%
#include <stdio.h>

void main()
{
   int a=5,b=6;
   if(a=b)
   printf("yes");
   else
   printf("no");
   printf("%d",a);
   
}

#include <stdio.h>

void main()
{
   int a=5,b=6;
   if(a!=b)
   printf("yes");
   else
   printf("no");
   printf("%d",a);
   
}

# %%
#include <stdio.h>

void main()
{
   int a=5,b;
   b=sizeof(a);
   printf("%d %d",a,b);
  
}

#include <stdio.h>

void main()
{
   int a=5,b=6,c;
   c=a<b?a:b;
   printf("%d",c);
  
}


#include <stdio.h>

void main()
{
   int a=6,b=5,c;
   c=a>b?0:1;
   printf("%d",c);
  
}

void main()
{
   int a=6,b=5,c;
   c=a?0:1;
   printf("%d",c);
  
}
